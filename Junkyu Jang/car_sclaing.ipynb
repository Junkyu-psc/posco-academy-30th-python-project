# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns

# %%
df_raw = pd.read_csv('Car.csv', encoding = 'euc-kr')
df_raw.head()
# Out:
#                                Name    Location     Price  Year  \
# 0            Maruti Wagon R LXI CNG      Mumbai   2682.68  2010
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                      Honda Jazz V     Chennai   6898.32  2011
# 3                 Maruti Ertiga VDI     Chennai   9197.76  2012
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First   26.6 kmpl   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price
# 0  58.16 bhp    5.0        NaN
# 1  126.2 bhp    5.0        NaN
# ...

# %%
df_raw.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# dtype: int64

# %%
df_raw[df_raw['Fuel_Type'] == 'Electric']
# Out:
#                            Name Location     Price  Year  Kilometers_Driven  \
# 4446       Mahindra E Verito D4  Chennai  19928.48  2016              50000
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  19545.24  2011              44000
#
#      Fuel_Type Transmission Owner_Type Mileage   Engine   Power  Seats  \
# 4446  Electric    Automatic      First     NaN    72 CC  41 bhp    5.0
# 4904  Electric    Automatic      First     NaN  1798 CC  73 bhp    5.0
#
#        New_Price
# 4446  13.58 Lakh
# 4904         NaN

# %%
df_raw[df_raw['Engine'].isnull()]
# Out:
#                                               Name    Location     Price  \
# 194                             Honda City 1.5 GXI   Ahmedabad   4522.23
# 208                           Maruti Swift 1.3 VXi     Kolkata   3234.55
# 733                           Maruti Swift 1.3 VXi     Chennai   2682.68
# 749                   Land Rover Range Rover 3.0 D      Mumbai  40623.44
# 1294                             Honda City 1.3 DX       Delhi   4905.47
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad   8891.17
# 1385                            Honda City 1.5 GXI        Pune   2299.44
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  62667.40
# 2074                          Maruti Swift 1.3 LXI        Pune   4828.82
# 2096                     Hyundai Santro LP zipPlus  Coimbatore   2958.61
# 2264                           Toyota Etios Liva V        Pune   4522.23
# 2325                      Maruti Swift 1.3 VXI ABS        Pune   7204.91
# ...

# %%
df_raw[df_raw['Power'].isnull()]
# Out:
#                                               Name    Location     Price  \
# 194                             Honda City 1.5 GXI   Ahmedabad   4522.23
# 208                           Maruti Swift 1.3 VXi     Kolkata   3234.55
# 733                           Maruti Swift 1.3 VXi     Chennai   2682.68
# 749                   Land Rover Range Rover 3.0 D      Mumbai  40623.44
# 1294                             Honda City 1.3 DX       Delhi   4905.47
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad   8891.17
# 1385                            Honda City 1.5 GXI        Pune   2299.44
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  62667.40
# 2074                          Maruti Swift 1.3 LXI        Pune   4828.82
# 2096                     Hyundai Santro LP zipPlus  Coimbatore   2958.61
# 2264                           Toyota Etios Liva V        Pune   4522.23
# 2325                      Maruti Swift 1.3 VXI ABS        Pune   7204.91
# ...

# %%
# 두 결측치 column이 동일
# 엔진 및 파워 결측치 처리
df1 = df_raw[df_raw['Power'].isnull()]
df2 = df_raw[df_raw['Engine'].isnull()]

df1.equals(df2)
# Out:
# True

# %% [markdown]
# ## 엔진 및 파워 결측치 처리

# %%
# 194행, 1385행, 5270행
df_raw[df_raw['Name'] == 'Honda City 1.5 GXI']
# Out:
#                     Name   Location    Price  Year  Kilometers_Driven  \
# 194   Honda City 1.5 GXI  Ahmedabad  4522.23  2007              60006
# 1385  Honda City 1.5 GXI       Pune  2299.44  2004             115000
# 3305  Honda City 1.5 GXI     Jaipur  3525.81  2007              75055
# 4767  Honda City 1.5 GXI     Mumbai  1686.26  2005              81000
# 5270  Honda City 1.5 GXI  Bangalore  2835.98  2002              53000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine    Power  Seats  \
# 194     Petrol       Manual      First   0.0 kmpl      NaN      NaN    NaN
# 1385    Petrol       Manual     Second   0.0 kmpl      NaN      NaN    NaN
# 3305    Petrol       Manual      First  12.8 kmpl  1493 CC  100 bhp    5.0
# 4767    Petrol       Manual     Second  12.8 kmpl  1493 CC  100 bhp    5.0
# 5270    Petrol       Manual     Second   0.0 kmpl      NaN      NaN    NaN
#
#      New_Price
# 194        NaN
# 1385       NaN
# 3305       NaN
# 4767       NaN
# ...

# %%
# 194행, 1385행, 5270행의 엔진 크기를 '1493 CC'로 수정
df_raw.loc[[194, 1385, 5270], 'Engine'] = '1493 CC'

# 194행, 1385행, 5270행의 파워를 '100 bhp'로 수정
df_raw.loc[[194, 1385, 5270], 'Power'] = '100 bhp'

# 194행, 1385행, 5270행의 시트 수를 '5.0'으로 수정
df_raw.loc[[194, 1385, 5270], 'Seats'] = 5.0

# 194행, 1385행, 5270행의 연비를 '12.8 kmpl'로 수정
df_raw.loc[[194, 1385, 5270], 'Mileage'] = '12.8 kmpl'

# %%
# 208행, 733행, 2335행, 3404행, 5015행, 6651행, 6685행
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Maruti Swift 1.3 VXi']
df_raw.drop(df_raw[df_raw['Name'] == 'Maruti Swift 1.3 VXi'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Land Rover Range Rover 3.0 D']
df_raw.drop(df_raw[df_raw['Name'] == 'Land Rover Range Rover 3.0 D'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Honda City 1.3 DX']
df_raw.drop(df_raw[df_raw['Name'] == 'Honda City 1.3 DX'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Maruti Swift 1.3 ZXI']
df_raw.drop(df_raw[df_raw['Name'] == 'Maruti Swift 1.3 ZXI'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제  
df_raw[df_raw['Name'] == 'Land Rover Range Rover Sport 2005 2012 Sport']
df_raw.drop(df_raw[df_raw['Name'] == 'Land Rover Range Rover Sport 2005 2012 Sport'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Maruti Swift 1.3 LXI']
df_raw.drop(df_raw[df_raw['Name'] == 'Maruti Swift 1.3 LXI'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Hyundai Santro LP zipPlus']
df_raw.drop(df_raw[df_raw['Name'] == 'Hyundai Santro LP zipPlus'].index, inplace=True)

# %%
# 2264행, 6902행
df_raw[df_raw['Name'] == 'Toyota Etios Liva V']
# Out:
#                      Name Location    Price  Year  Kilometers_Driven  \
# 2264  Toyota Etios Liva V     Pune  4522.23  2012              24500
# 4138  Toyota Etios Liva V   Mumbai  5442.01  2013               8950
# 6902  Toyota Etios Liva V    Kochi      NaN  2012              59311
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine     Power  Seats  \
# 2264    Petrol       Manual     Second   18.3 kmpl      NaN       NaN    NaN
# 4138    Petrol       Manual      First  17.71 kmpl  1197 CC  78.9 bhp    5.0
# 6902    Petrol       Manual      First   18.3 kmpl      NaN       NaN    NaN
#
#      New_Price
# 2264       NaN
# 4138       NaN
# 6902       NaN

# %%
# 2264행, 6902행의 엔진 크기를 '1197 CC'로 수정
df_raw.loc[[2264, 6902], 'Engine'] = '1197 CC'

# 2264행, 6902행의 파워를 '78.9 bhp'로 수정
df_raw.loc[[2264, 6902], 'Power'] = '78.9 bhp'

# 2264행, 6902행의 시트 수를 '5.0'으로 수정
df_raw.loc[[2264, 6902], 'Seats'] = 5.0

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Maruti Swift 1.3 VXI ABS']
df_raw.drop(df_raw[df_raw['Name'] == 'Maruti Swift 1.3 VXI ABS'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'BMW 5 Series 520d Sedan']
df_raw.drop(df_raw[df_raw['Name'] == 'BMW 5 Series 520d Sedan'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Hyundai Santro GLS II - Euro II']
df_raw.drop(df_raw[df_raw['Name'] == 'Hyundai Santro GLS II - Euro II'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Maruti Wagon R Vx']
df_raw.drop(df_raw[df_raw['Name'] == 'Maruti Wagon R Vx'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Honda CR-V AT With Sun Roof']
df_raw.drop(df_raw[df_raw['Name'] == 'Honda CR-V AT With Sun Roof'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Fiat Punto 1.3 Emotion']
df_raw.drop(df_raw[df_raw['Name'] == 'Fiat Punto 1.3 Emotion'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Hyundai Santro Xing XG']
df_raw.drop(df_raw[df_raw['Name'] == 'Hyundai Santro Xing XG'].index, inplace=True)

# %%
# 4604행
df_raw[df_raw['Name'] == 'Honda Jazz Select Edition']
# Out:
#                            Name Location    Price  Year  Kilometers_Driven  \
# 3145  Honda Jazz Select Edition  Kolkata  3050.59  2010              45000
# 4604  Honda Jazz Select Edition     Pune  4828.82  2011              98000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine     Power  Seats  \
# 3145    Petrol       Manual      First  16.7 kmpl  1198 CC  88.8 bhp    5.0
# 4604    Petrol       Manual      First  16.7 kmpl      NaN       NaN    NaN
#
#      New_Price
# 3145       NaN
# 4604       NaN

# %%
# 4604행의 엔진 크기를 '1198 CC'로 수정
df_raw.loc[4604, 'Engine'] = '1198 CC'

# 4604행의 파워를 '88.8 bhp'로 수정
df_raw.loc[4604, 'Power'] = '88.8 bhp'

# 4604행의 시트 수를 '5.0'으로 수정
df_raw.loc[4604, 'Seats'] = 5.0

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Fiat Punto 1.2 Dynamic']
df_raw.drop(df_raw[df_raw['Name'] == 'Fiat Punto 1.2 Dynamic'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Fiat Punto 1.4 Emotion']
df_raw.drop(df_raw[df_raw['Name'] == 'Fiat Punto 1.4 Emotion'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Skoda Laura 1.8 TSI Ambition']
df_raw.drop(df_raw[df_raw['Name'] == 'Skoda Laura 1.8 TSI Ambition'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Toyota Etios Liva Diesel TRD Sportivo']
df_raw.drop(df_raw[df_raw['Name'] == 'Toyota Etios Liva Diesel TRD Sportivo'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Hyundai i20 new Sportz AT 1.4']
df_raw.drop(df_raw[df_raw['Name'] == 'Hyundai i20 new Sportz AT 1.4'].index, inplace=True)

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw[df_raw['Name'] == 'Mahindra TUV 300 P4']
df_raw.drop(df_raw[df_raw['Name'] == 'Mahindra TUV 300 P4'].index, inplace=True)

# %%
# 결측치 처리 완료
df_raw[df_raw['Power'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Price, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price]
# Index: []

# %% [markdown]
# #### 결과 : Honda City 1.5 GXI 3대, Toyota Etios Liva V 2대, Honda Jazz Select Edition 1대 결측치 처리 완료

# %% [markdown]
# ## 시트 수 결측치 처리

# %%
# 시트 수 결측치 처리
df_raw[df_raw['Seats'].isnull()]
# Out:
#                              Name   Location     Price  Year  \
# 229              Ford Figo Diesel  Bangalore   5518.66  2015
# 1917           Honda City 1.5 EXI     Jaipur   2606.03  2005
# 2369            Maruti Estilo LXI    Chennai   2299.44  2008
# 3800  Ford Endeavour Hurricane LE     Mumbai  10730.72  2012
# 3882            Maruti Estilo LXI    Kolkata   3832.40  2010
# 5893            Maruti Estilo LXI    Chennai   2682.68  2008
# 6957       Honda Jazz 2020 Petrol      Kochi       NaN  2019
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type    Mileage   Engine  \
# 229               70436    Diesel       Manual      First   0.0 kmpl  1498 CC
# 1917              88000    Petrol       Manual     Second  13.0 kmpl  1493 CC
# 2369              56000    Petrol       Manual     Second  19.5 kmpl  1061 CC
# 3800             129000    Diesel    Automatic      First  12.8 kmpl  2953 CC
# 3882              40000    Petrol       Manual     Second  19.5 kmpl  1061 CC
# ...

# %%
df_raw[df_raw['Name'] == 'Ford Figo Diesel']
# Out:
#                  Name   Location    Price  Year  Kilometers_Driven Fuel_Type  \
# 229  Ford Figo Diesel  Bangalore  5518.66  2015              70436    Diesel
#
#     Transmission Owner_Type   Mileage   Engine   Power  Seats New_Price
# 229       Manual      First  0.0 kmpl  1498 CC  99 bhp    NaN       NaN

# %%
# 인터넷 검색을 통해 5.0인승으로 확인
df_raw.loc[229, 'Seats'] = 5.0

# %%
df_raw[df_raw['Name'] == 'Honda City 1.5 EXI']
# Out:
#                     Name    Location    Price  Year  Kilometers_Driven  \
# 1279  Honda City 1.5 EXI        Pune  1762.90  2005              98437
# 1917  Honda City 1.5 EXI      Jaipur  2606.03  2005              88000
# 3721  Honda City 1.5 EXI      Jaipur  1686.26  2005             123000
# 3806  Honda City 1.5 EXI        Pune  2222.79  2001             125943
# 5957  Honda City 1.5 EXI  Coimbatore  2698.01  2004             186679
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine    Power  Seats  \
# 1279    Petrol       Manual      First  13.0 kmpl  1493 CC  100 bhp    5.0
# 1917    Petrol       Manual     Second  13.0 kmpl  1493 CC  100 bhp    NaN
# 3721    Petrol       Manual      Third  13.0 kmpl  1493 CC  100 bhp    5.0
# 3806    Petrol       Manual     Second  13.0 kmpl  1493 CC  100 bhp    5.0
# 5957    Petrol       Manual     Second  13.0 kmpl  1493 CC  100 bhp    5.0
#
#      New_Price
# 1279       NaN
# 1917       NaN
# 3721       NaN
# 3806       NaN
# ...

# %%
# 1917행
df_raw.loc[1917, 'Seats'] = 5.0

# %%
df_raw[df_raw['Name'] == 'Maruti Estilo LXI']
# Out:
#                    Name Location    Price  Year  Kilometers_Driven Fuel_Type  \
# 2369  Maruti Estilo LXI  Chennai  2299.44  2008              56000    Petrol
# 3882  Maruti Estilo LXI  Kolkata  3832.40  2010              40000    Petrol
# 5893  Maruti Estilo LXI  Chennai  2682.68  2008              51000    Petrol
#
#      Transmission Owner_Type    Mileage   Engine     Power  Seats New_Price
# 2369       Manual     Second  19.5 kmpl  1061 CC  null bhp    NaN       NaN
# 3882       Manual     Second  19.5 kmpl  1061 CC  null bhp    NaN       NaN
# 5893       Manual     Second  19.5 kmpl  1061 CC  null bhp    NaN       NaN

# %%
# 인터넷 검색을 통해 5.0인승으로 확인
df_raw.loc[[2369, 3882, 5893], 'Seats'] = 5.0

# %%
df_raw[df_raw['Name'] == 'Ford Endeavour Hurricane LE']
# Out:
#                              Name Location     Price  Year  Kilometers_Driven  \
# 3800  Ford Endeavour Hurricane LE   Mumbai  10730.72  2012             129000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine     Power  Seats  \
# 3800    Diesel    Automatic      First  12.8 kmpl  2953 CC  null bhp    NaN
#
#      New_Price
# 3800       NaN

# %%
# 인터넷 검색을 통해 7.0인승으로 확인
df_raw.loc[3800, 'Seats'] = 7.0

# %%
df_raw[df_raw['Name'] == 'Honda Jazz 2020 Petrol']
# Out:
#                         Name Location  Price  Year  Kilometers_Driven  \
# 6957  Honda Jazz 2020 Petrol    Kochi    NaN  2019              11574
#
#      Fuel_Type Transmission Owner_Type   Mileage   Engine     Power  Seats  \
# 6957    Petrol       Manual      First  0.0 kmpl  1199 CC  88.7 bhp    NaN
#
#      New_Price
# 6957       NaN

# %%
# 인터넷 검색을 통해 5.0인승으로 확인
df_raw.loc[[6957], 'Seats'] = 5.0

# %%
# 결측치 처리 완료
df_raw[df_raw['Seats'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Price, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price]
# Index: []

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7213 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7213 non-null   object
#  1   Location           7213 non-null   object
#  2   Price              6169 non-null   float64
#  3   Year               7213 non-null   int64
#  4   Kilometers_Driven  7213 non-null   int64
#  5   Fuel_Type          7213 non-null   object
#  6   Transmission       7213 non-null   object
#  7   Owner_Type         7213 non-null   object
#  8   Mileage            7211 non-null   object
#  9   Engine             7213 non-null   object
#  10  Power              7213 non-null   object
#  11  Seats              7213 non-null   float64
#  12  New_Price          1006 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# #### 결과 : 차량 비교 후 결측치 처리 완료, 자료 없는 차량은 구글링으로 대체

# %% [markdown]
# ## 연비 결측치 처리

# %%
df_raw[df_raw['Mileage'].isnull()]
# Out:
#                            Name Location     Price  Year  Kilometers_Driven  \
# 4446       Mahindra E Verito D4  Chennai  19928.48  2016              50000
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  19545.24  2011              44000
#
#      Fuel_Type Transmission Owner_Type Mileage   Engine   Power  Seats  \
# 4446  Electric    Automatic      First     NaN    72 CC  41 bhp    5.0
# 4904  Electric    Automatic      First     NaN  1798 CC  73 bhp    5.0
#
#        New_Price
# 4446  13.58 Lakh
# 4904         NaN

# %%
df_raw[df_raw['Name'] == 'Mahindra E Verito D4']
# Out:
#                       Name Location     Price  Year  Kilometers_Driven  \
# 4446  Mahindra E Verito D4  Chennai  19928.48  2016              50000
#
#      Fuel_Type Transmission Owner_Type Mileage Engine   Power  Seats  \
# 4446  Electric    Automatic      First     NaN  72 CC  41 bhp    5.0
#
#        New_Price
# 4446  13.58 Lakh

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw.drop(df_raw[df_raw['Name'] == 'Mahindra E Verito D4'].index, inplace=True)

# %%
df_raw[df_raw['Name'] == 'Toyota Prius 2009-2016 Z4']
# Out:
#                            Name Location     Price  Year  Kilometers_Driven  \
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  19545.24  2011              44000
#
#      Fuel_Type Transmission Owner_Type Mileage   Engine   Power  Seats  \
# 4904  Electric    Automatic      First     NaN  1798 CC  73 bhp    5.0
#
#      New_Price
# 4904       NaN

# %%
# 수정을 위한 비교 자료가 존재하지 않음
# 삭제
df_raw.drop(df_raw[df_raw['Name'] == 'Toyota Prius 2009-2016 Z4'].index, inplace=True)

# %%
# 연비 결측치 처리 완료
df_raw[df_raw['Mileage'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Price, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price]
# Index: []

# %% [markdown]
# #### 결과 : 자료 수가 적어, 없애는 것으로 결론

# %%
df_raw.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1044
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            6206
# dtype: int64

# %% [markdown]
# ## 이상치 처리

# %%
# 도형이가 연비 결측치 발견했다고 해서 확인
plt.scatter(df_raw['Mileage'], df_raw['Price'], alpha=0.6, color='blue')

plt.xlabel('Mileage (km/l)')
plt.ylabel('Price (₹)')
plt.title('Car Price vs Mileage')
plt.show()

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7211 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7211 non-null   object
#  1   Location           7211 non-null   object
#  2   Price              6167 non-null   float64
#  3   Year               7211 non-null   int64
#  4   Kilometers_Driven  7211 non-null   int64
#  5   Fuel_Type          7211 non-null   object
#  6   Transmission       7211 non-null   object
#  7   Owner_Type         7211 non-null   object
#  8   Mileage            7211 non-null   object
#  9   Engine             7211 non-null   object
#  10  Power              7211 non-null   object
#  11  Seats              7211 non-null   float64
#  12  New_Price          1005 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 788.7+ KB

# %%
df_raw.to_csv('updated_Car.csv', index = False)
